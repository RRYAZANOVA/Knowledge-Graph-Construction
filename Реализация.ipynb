# %% [markdown]
# **Задание для лабораторной №7:**
# 1. Построить базу знаний в любой предметной области, сформировав массив документов (например, публикаций или файлов на каком-либо портале или набор файлов на компьютере или сервере и т.п.) и построить граф знаний об этих документах
# 2. Реализовать сервис краткого описания каждого документа в базе знаний (абстракт, автореферат - summary)
# 3. Реализовать сервис поиска по запросу внутри базы знаний (вопрос-ответный модуль)

# %% [markdown]
# ### 0. Загрузка данных

# %% [markdown]
# Данные взяты с сайта: https://ru.wikipedia.org/wiki/Категория:Знаменитые_животные_по_алфавиту

# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import time

# %%
os.makedirs('famous_animals', exist_ok=True)

# %%
base_url = 'https://ru.wikipedia.org'
category_url = f'{base_url}/wiki/Категория:Знаменитые_животные_по_алфавиту'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

# %%
response = requests.get(category_url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
content_div = soup.find('div', {'id': 'mw-pages'})
if content_div:
    animal_links = content_div.find_all('a')
else:
    animal_links = []

# %%
print(f"Найдено животных: {len(animal_links)}")

for link in animal_links:
    animal_name = link.text
    animal_href = link.get('href')
    if not animal_href or not animal_href.startswith('/wiki/'):
        continue
    animal_url = base_url + animal_href

    try:

        time.sleep(1)

        animal_response = requests.get(animal_url, headers=headers)
        if animal_response.status_code == 429:
            print(f"Too many requests for {animal_name}. Waiting...")
            time.sleep(10)
            continue

        animal_soup = BeautifulSoup(animal_response.content, 'html.parser')

        paragraphs = animal_soup.find_all('p')
        description = ''
        for p in paragraphs:
            if p.text.strip() and len(p.text.strip()) > 50:
                description = p.text.strip()
                break

        infobox = animal_soup.find('table', {'class': 'infobox'})
        animal_type = "Неизвестно"
        birth_date = "Неизвестно"

        if infobox:
            rows = infobox.find_all('tr')
            for r in rows:
                if r.th:
                    header = r.th.text.strip()
                    if "вид" in header.lower():
                        animal_type = r.td.text.strip()
                    if "дата рождения" in header.lower() or "дата появления" in header.lower():
                        birth_date = r.td.text.strip()

        # Если описание не найдено, пишем заглушку
        if not description:
            description = "Описание недоступно."

        animal_data = {
            'Название': animal_name,
            'Описание': description,
            'Вид животного': animal_type,
            'Дата рождения': birth_date,
            'Ссылка': animal_url
        }

        filename = f"famous_animals/{animal_name.replace('/', '_')}.json"
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(animal_data, f, ensure_ascii=False, indent=4)

        print(f"Сохранено: {animal_name}")

    except Exception as e:
        print(f"Ошибка при обработке {animal_name}: {e}")
# Out:
# Найдено животных: 207
# Сохранено: Список ниже может не отражать последних изменений.
# Сохранено: Искать по категории
# Сохранено: Случайная страница в категории
# Сохранено: Абсент (конь)
# Сохранено: Абу-ль-Аббас (слон)
# Сохранено: Абутью
# Сохранено: Адвайта (черепаха)
# Сохранено: Алекс (попугай)
# Сохранено: Аллентонский бегемот
# Сохранено: Амадей (тигр)
# Сохранено: Амур и Тимур
# Сохранено: Ангалифу
# Сохранено: Анилин (конь)
# Сохранено: Анна Савельевна
# Сохранено: Ань Ань
# Сохранено: Ань-Ань
# Сохранено: Арго (волк)
# Сохранено: Байерли Тюрк
# Сохранено: Балто
# Сохранено: Барни (собака)
# Сохранено: Барри (собака)
# Сохранено: Барт (медведь)
# Сохранено: Баська Мурманская
# Сохранено: Батыр (слон)
# Сохранено: Бахати (львенок)
# Сохранено: Белка и Стрелка
# Сохранено: Берёзовский мамонт
# Сохранено: Берт (крокодил)
# Сохранено: Блонди
# Сохранено: Бо Обама
# Сохранено: Боби (пёс)
# Сохранено: Бой (пудель)
# Сохранено: Бокито (горилла)
# Сохранено: Большой Шлёпа
# Сохранено: Борец (медведь)
# Сохранено: Борис (собака)
# Сохранено: Бричес (обезьяна)
# Сохранено: Бу (собака)
# Сохранено: Буджан Сэнан
# Сохранено: Буммер и Лазарус
# Сохранено: Буцефал
# Сохранено: Ветерок и Уголёк
# Сохранено: Вилли (собака)
# Сохранено: Виннипег (медведица)
# Сохранено: Винтер (дельфин)
# Сохранено: Войтек (медведь)
# Сохранено: Габи (слон)
# Сохранено: Ганготри (корова)
# Сохранено: Гарриета (черепаха)
# Сохранено: Гастон (морской котик)
# Сохранено: Гацек (кот)
# Сохранено: Гелерт (мифология)
# Сохранено: Геркулес (лигр)
# Сохранено: Гинфорт
# Сохранено: Гли (кошка)
# Сохранено: Годзилла (крокодил)
# Сохранено: Годольфин Арабиан
# Сохранено: Грейфрайерс Бобби
# Сохранено: Грипсхольмский лев
# Сохранено: Губерта
# Сохранено: Гувер (тюлень)
# Сохранено: Гуруваюр Кешаван
# Сохранено: Густав (крокодил)
# Сохранено: Дарли Арабиан
# Сохранено: Дезик и Цыган
# Сохранено: Джакко Макакко
# Сохранено: Джамбо
# Сохранено: Джек (павиан)
# Сохранено: Джек (собака)
# Сохранено: Джеки (павиан)
# Сохранено: Джо Мартин (орангутан)
# Сохранено: Джонатан (черепаха)
# Сохранено: Джуди (собака)
# Сохранено: Джульбарс (собака)
# Сохранено: Диего (черепаха)
# Сохранено: Дизель (собака)
# Сохранено: Дик (собака)
# Сохранено: Киргиляхский мамонт
# Сохранено: Дина (собака)
# Сохранено: Долли (овца)
# Сохранено: Доминомюс
# Сохранено: Дьюи Читатель Книг
# Сохранено: Дэш (собака)
# Сохранено: Дюймовочка (карликовая лошадь)
# Сохранено: Егор (белуха)
# Сохранено: Енот из Херсона
# Сохранено: Жеводанский зверь
# Сохранено: Железный Ковбой
# Сохранено: Жираф Медичи
# Сохранено: Жулька и Жемчужина
# Сохранено: Забродский тигр
# Сохранено: Занджир
# Сохранено: Заратустра (кот)
# Сохранено: Зарафа
# Сохранено: Звёздочка (собака-космонавт)
# Сохранено: Земира
# Сохранено: Зиппи Чиппи
# Сохранено: Золушка (тигрица)
# Сохранено: Инджаз
# Сохранено: Индия (кошка)
# Сохранено: Инцитат
# Сохранено: Йале (собака)
# Сохранено: Кабосу (собака)
# Сохранено: Кагуя (мышь)
# Сохранено: Кадо (пойнтер)
# Сохранено: Какареко
# Сохранено: Камиль (медведь)
# Сохранено: Канзи
# Сохранено: Кассиус (крокодил)
# Сохранено: Кастор и Поллукс (слоны)
# Сохранено: Кашмир (конь)
# Сохранено: Квадрат (конь)
# Сохранено: Кейко
# Сохранено: Кики (черепаха)
# Сохранено: Кинули
# Сохранено: Клара (носорог)
# Сохранено: Кнут (медведь)
# Сохранено: Кобыла лорда Мортона
# Сохранено: Кокаиновый медведь (медведь)
# Сохранено: Коко (горилла)
# Сохранено: Коко (собака)
# Сохранено: Команч (конь)
# Сохранено: Конго (шимпанзе)
# Сохранено: Конни Полгрейв
# Сохранено: Крепыш
# Сохранено: Крим Пафф
# Сохранено: Кристал (обезьяна)
# Сохранено: Крымский Том
# Сохранено: Кузнечик (верблюд)
# Сохранено: Кузя (кондор)
# Сохранено: Кузя (тигр)
# Сохранено: Куки (какаду)
# Сохранено: Кумир (конь)
# Сохранено: Кхосик
# Сохранено: Лайка (собака-космонавт)
# Сохранено: Ларри (кот)
# Сохранено: Ленский мамонт
# Сохранено: Лео (собака)
# Сохранено: Леопард из Рудрапраяга
# Сохранено: Лил Баб
# Сохранено: Лимбербатт Маккуббинс
# Сохранено: Лин-Лин (большая панда)
# Сохранено: Линь Ван (слон)
# Сохранено: Лисичка и Чайка
# Сохранено: Лолита (косатка)
# Сохранено: Лолонг
# Сохранено: Луга (жирафа)
# Сохранено: Луканикос
# Сохранено: Мамонтёнок Люба
# Сохранено: Людоеды из Цаво
# Сохранено: Лютый (тигр)
# Сохранено: Магава
# Сохранено: Майк (безголовый петух)
# Сохранено: Майкл (горилла)
# Сохранено: Максвелл (кот)
# Сохранено: Мальчик (собака)
# Сохранено: Мамонт Петя
# Сохранено: Манч (собака)
# Сохранено: Марта (странствующий голубь)
# Сохранено: Мару (кот)
# Сохранено: Марьям (медведица)
# Сохранено: Матроска (кошка)
# Сохранено: Маша (медведица)
# Сохранено: Месси (пума)
# Сохранено: Микки (шимпанзе)
# Сохранено: Милли (собака)
# Сохранено: Мин (моллюск)
# Сохранено: Мисс Бейкер
# Сохранено: Мисс Бизли (собака)
# Сохранено: Мотти (слонёнок)
# Сохранено: Му Денг
# Сохранено: Муизза
# Сохранено: Мука (кошка)
# Сохранено: Мусташ (собака)
# Сохранено: Мухамед (конь)
# Сохранено: Мэй Сян
# Сохранено: Мэйджор (собака)
# Сохранено: Мэри (слониха)
# Сохранено: Мяу (кот)
# Сохранено: Надежда (таракан)
# Сохранено: Неджем
# Сохранено: Непотопляемый Сэм
# Сохранено: Нильс Улаф
# Сохранено: Ним Чимпский
# Сохранено: Нола (носорог)
# Сохранено: Нора (кошка)
# Сохранено: Обайш
# Сохранено: Одинокий Джордж
# Сохранено: Оззи (горилла)
# Сохранено: Олд Боб
# Сохранено: Олд Джок
# Сохранено: Оранджи
# Сохранено: Оскар (кот)
# Сохранено: Отважная (собака-космонавт)
# Сохранено: Отто (собака)
# Сохранено: Палмерстон (кот)
# Сохранено: Патрон (пёс)
# Сохранено: Пауль (осьминог)
# Сохранено: Пегги (собака)
# Сохранено: Пелорус Джек
# Сохранено: Пета (кошка)
# Сохранено: Петра (лебедь)
# Сохранено: Петрос (пеликан)

# %%
folder_path = 'famous_animals'

# Список служебных слов
bad_words = ['список', 'искать', 'страница', 'категория', 'изменений', 'случайная']

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            name = data.get('Название', '').lower()

            if any(bad_word in name for bad_word in bad_words):
                print(f"Удаляю: {filename}")
                os.remove(file_path)

    except Exception as e:
        print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Удаляю: Искать по категории.json
# Удаляю: Случайная страница в категории.json
# Удаляю: Список ниже может не отражать последних изменений..json

# %%
folder_path = 'famous_animals'

missing_description = 0
missing_type = 0
missing_birth = 0
total_files = 0

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                total_files += 1

                if data.get('Описание', '') == "Описание недоступно.":
                    missing_description += 1
                if data.get('Вид животного', '') == "Неизвестно":
                    missing_type += 1
                if data.get('Дата рождения', '') == "Неизвестно":
                    missing_birth += 1

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

print(f"Всего файлов: {total_files}")
print(f"Без описания: {missing_description}")
print(f"Без указания вида: {missing_type}")
print(f"Без даты рождения: {missing_birth}")
# Out:
# Всего файлов: 293
# Без описания: 0
# Без указания вида: 67
# Без даты рождения: 61

# %%
import re

folder_path = 'famous_animals'

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            name = data.get('Название', '')
            animal_type = data.get('Вид животного', 'Неизвестно')

            match = re.match(r'(.+?)\s*\((.+?)\)', name)
            if match:
                clean_name = match.group(1).strip()
                type_in_brackets = match.group(2).strip()

                data['Название'] = clean_name

                if animal_type == "Неизвестно" or not animal_type:
                    data['Вид животного'] = type_in_brackets

                new_filename = f"{clean_name.replace('/', '_')}.json"
                new_path = os.path.join(folder_path, new_filename)

                os.remove(file_path)
                with open(new_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=4)

            else:
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=4)

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

# %%
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            animal_type = data.get('Вид животного', '')
            animal_year = data.get('Дата рождения', '')

            # Если вид животного "Неизвестно" — удаляем файл
            if animal_type.strip().lower() == 'неизвестно':
                print(f"Удаляю файл без вида: {filename}")
                os.remove(file_path)

            if animal_year.strip().lower() == 'неизвестно':
                print(f"Удаляю файл без года рождения: {filename}")
                os.remove(file_path)


        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Удаляю файл без вида: Берёзовский мамонт.json
# Удаляю файл без года рождения: Берёзовский мамонт.json
# Ошибка при обработке Берёзовский мамонт.json: [Errno 2] No such file or directory: 'famous_animals/Берёзовский мамонт.json'
# Удаляю файл без вида: Аллентонский бегемот.json
# Удаляю файл без года рождения: Аллентонский бегемот.json
# Ошибка при обработке Аллентонский бегемот.json: [Errno 2] No such file or directory: 'famous_animals/Аллентонский бегемот.json'
# Удаляю файл без вида: Баська Мурманская.json
# Удаляю файл без года рождения: Баська Мурманская.json
# Ошибка при обработке Баська Мурманская.json: [Errno 2] No such file or directory: 'famous_animals/Баська Мурманская.json'
# Удаляю файл без вида: Канзи.json
# Удаляю файл без вида: Гуруваюр Кешаван.json
# Удаляю файл без вида: Обайш.json
# Удаляю файл без года рождения: Обайш.json
# Ошибка при обработке Обайш.json: [Errno 2] No such file or directory: 'famous_animals/Обайш.json'
# Удаляю файл без года рождения: Ларри.json
# Удаляю файл без года рождения: Йале.json
# Удаляю файл без вида: Губерта.json
# Удаляю файл без года рождения: Губерта.json
# Ошибка при обработке Губерта.json: [Errno 2] No such file or directory: 'famous_animals/Губерта.json'
# Удаляю файл без вида: Годольфин Арабиан.json
# Удаляю файл без года рождения: Годольфин Арабиан.json
# Ошибка при обработке Годольфин Арабиан.json: [Errno 2] No such file or directory: 'famous_animals/Годольфин Арабиан.json'
# Удаляю файл без года рождения: Матроска.json
# Удаляю файл без года рождения: Гелерт.json
# Удаляю файл без года рождения: Кузнечик.json
# Удаляю файл без года рождения: Енот из Херсона.json
# Удаляю файл без вида: Ним Чимпский.json
# Удаляю файл без года рождения: Лео.json
# Удаляю файл без вида: Байерли Тюрк.json
# Удаляю файл без года рождения: Байерли Тюрк.json
# Ошибка при обработке Байерли Тюрк.json: [Errno 2] No such file or directory: 'famous_animals/Байерли Тюрк.json'
# Удаляю файл без вида: Буммер и Лазарус.json
# Удаляю файл без года рождения: Буммер и Лазарус.json
# Ошибка при обработке Буммер и Лазарус.json: [Errno 2] No such file or directory: 'famous_animals/Буммер и Лазарус.json'
# Удаляю файл без вида: Кобыла лорда Мортона.json
# Удаляю файл без года рождения: Кобыла лорда Мортона.json
# Ошибка при обработке Кобыла лорда Мортона.json: [Errno 2] No such file or directory: 'famous_animals/Кобыла лорда Мортона.json'
# Удаляю файл без года рождения: Дезик и Цыган.json
# Удаляю файл без года рождения: Бричес.json
# Удаляю файл без года рождения: Команч.json
# Удаляю файл без года рождения: Петра.json
# Удаляю файл без вида: Джакко Макакко.json
# Удаляю файл без года рождения: Джакко Макакко.json
# Ошибка при обработке Джакко Макакко.json: [Errno 2] No such file or directory: 'famous_animals/Джакко Макакко.json'
# Удаляю файл без вида: Гинфорт.json
# Удаляю файл без года рождения: Гинфорт.json
# Ошибка при обработке Гинфорт.json: [Errno 2] No such file or directory: 'famous_animals/Гинфорт.json'
# Удаляю файл без года рождения: Надежда.json
# Удаляю файл без года рождения: Палмерстон.json
# Удаляю файл без года рождения: Ветерок и Уголёк.json
# Удаляю файл без года рождения: Лолонг.json
# Удаляю файл без года рождения: Кумир.json
# Удаляю файл без года рождения: Петрос.json
# Удаляю файл без вида: Дарли Арабиан.json
# Удаляю файл без года рождения: Дарли Арабиан.json
# Ошибка при обработке Дарли Арабиан.json: [Errno 2] No such file or directory: 'famous_animals/Дарли Арабиан.json'
# Удаляю файл без вида: Мамонтёнок Люба.json
# Удаляю файл без года рождения: Мамонтёнок Люба.json
# Ошибка при обработке Мамонтёнок Люба.json: [Errno 2] No such file or directory: 'famous_animals/Мамонтёнок Люба.json'
# Удаляю файл без года рождения: Отважная.json
# Удаляю файл без вида: Крим Пафф.json
# Удаляю файл без года рождения: Пелорус Джек.json
# Удаляю файл без года рождения: Марта.json
# Удаляю файл без вида: Абутью.json
# Удаляю файл без года рождения: Абутью.json
# Ошибка при обработке Абутью.json: [Errno 2] No such file or directory: 'famous_animals/Абутью.json'
# Удаляю файл без года рождения: Луканикос.json
# Удаляю файл без года рождения: Жулька и Жемчужина.json
# Удаляю файл без вида: Кхосик.json
# Удаляю файл без года рождения: Кхосик.json
# Ошибка при обработке Кхосик.json: [Errno 2] No such file or directory: 'famous_animals/Кхосик.json'
# Удаляю файл без вида: Крепыш.json
# Удаляю файл без года рождения: Крепыш.json
# Ошибка при обработке Крепыш.json: [Errno 2] No such file or directory: 'famous_animals/Крепыш.json'
# Удаляю файл без года рождения: Джульбарс.json
# Удаляю файл без года рождения: Лисичка и Чайка.json
# Удаляю файл без года рождения: Егор.json
# Удаляю файл без вида: Жеводанский зверь.json
# Удаляю файл без года рождения: Жеводанский зверь.json
# Ошибка при обработке Жеводанский зверь.json: [Errno 2] No such file or directory: 'famous_animals/Жеводанский зверь.json'
# Удаляю файл без года рождения: Мухамед.json
# Удаляю файл без вида: Доминомюс.json
# Удаляю файл без года рождения: Звёздочка.json
# Удаляю файл без года рождения: Леопард из Рудрапраяга.json
# Удаляю файл без года рождения: Квадрат.json
# Удаляю файл без вида: Грипсхольмский лев.json
# Удаляю файл без года рождения: Грипсхольмский лев.json
# Ошибка при обработке Грипсхольмский лев.json: [Errno 2] No such file or directory: 'famous_animals/Грипсхольмский лев.json'
# Удаляю файл без года рождения: Лимбербатт Маккуббинс.json
# Удаляю файл без года рождения: Забродский тигр.json
# Удаляю файл без года рождения: Мука.json
# Удаляю файл без года рождения: Кастор и Поллукс.json
# Удаляю файл без года рождения: Джек.json
# Удаляю файл без вида: Зиппи Чиппи.json
# Удаляю файл без вида: Жираф Медичи.json
# Удаляю файл без года рождения: Жираф Медичи.json
# Ошибка при обработке Жираф Медичи.json: [Errno 2] No such file or directory: 'famous_animals/Жираф Медичи.json'
# Удаляю файл без года рождения: Джеки.json
# Удаляю файл без вида: Инцитат.json
# Удаляю файл без года рождения: Инцитат.json
# Ошибка при обработке Инцитат.json: [Errno 2] No such file or directory: 'famous_animals/Инцитат.json'
# Удаляю файл без вида: Буцефал.json
# Удаляю файл без года рождения: Буцефал.json
# Ошибка при обработке Буцефал.json: [Errno 2] No such file or directory: 'famous_animals/Буцефал.json'
# Удаляю файл без года рождения: Анна Савельевна.json
# Удаляю файл без вида: Людоеды из Цаво.json
# Удаляю файл без года рождения: Людоеды из Цаво.json
# Ошибка при обработке Людоеды из Цаво.json: [Errno 2] No such file or directory: 'famous_animals/Людоеды из Цаво.json'
# Удаляю файл без вида: Киргиляхский мамонт.json
# Удаляю файл без года рождения: Киргиляхский мамонт.json
# Ошибка при обработке Киргиляхский мамонт.json: [Errno 2] No such file or directory: 'famous_animals/Киргиляхский мамонт.json'
# Удаляю файл без вида: Мамонт Петя.json
# Удаляю файл без года рождения: Мамонт Петя.json
# Ошибка при обработке Мамонт Петя.json: [Errno 2] No such file or directory: 'famous_animals/Мамонт Петя.json'
# Удаляю файл без вида: Ленский мамонт.json
# Удаляю файл без года рождения: Ленский мамонт.json
# Ошибка при обработке Ленский мамонт.json: [Errno 2] No such file or directory: 'famous_animals/Ленский мамонт.json'
# Удаляю файл без года рождения: Белка и Стрелка.json
# Удаляю файл без вида: Одинокий Джордж.json
# Удаляю файл без вида: Ань Ань.json
# Удаляю файл без года рождения: Ганготри.json

# %%
print(f"Всего файлов: {total_files}")
print(f"Без описания: {missing_description}")
print(f"Без указания вида: {missing_type}")
print(f"Без даты рождения: {missing_birth}")
# Out:
# Всего файлов: 293
# Без описания: 0
# Без указания вида: 67
# Без даты рождения: 61

# %%
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            if 'Страна' not in data:
                data['Страна'] = "Неизвестно"

                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=4)

                print(f"Добавлена страна в: {filename}")

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Добавлена страна в: Кузя.json
# Добавлена страна в: Джонатан.json
# Добавлена страна в: Железный Ковбой.json
# Добавлена страна в: Луга.json
# Добавлена страна в: Абу-ль-Аббас.json
# Добавлена страна в: Диего.json
# Добавлена страна в: Арго.json
# Добавлена страна в: Большой Шлёпа.json
# Добавлена страна в: Мэйджор.json
# Добавлена страна в: Пегги.json
# Добавлена страна в: Нильс Улаф.json
# Добавлена страна в: Оскар.json
# Добавлена страна в: Анилин.json
# Добавлена страна в: Годзилла.json
# Добавлена страна в: Дик.json
# Добавлена страна в: Линь Ван.json
# Добавлена страна в: Батыр.json
# Добавлена страна в: Манч.json
# Добавлена страна в: Балто.json
# Добавлена страна в: Земира.json
# Добавлена страна в: Майкл.json
# Добавлена страна в: Виннипег.json
# Добавлена страна в: Зарафа.json
# Добавлена страна в: Борец.json
# Добавлена страна в: Бокито.json
# Добавлена страна в: Гли.json
# Добавлена страна в: Барри.json
# Добавлена страна в: Гувер.json
# Добавлена страна в: Дина.json
# Добавлена страна в: Барни.json
# Добавлена страна в: Мотти.json
# Добавлена страна в: Занджир.json
# Добавлена страна в: Клара.json
# Добавлена страна в: Ангалифу.json
# Добавлена страна в: Кристал.json
# Добавлена страна в: Неджем.json
# Добавлена страна в: Боби.json
# Добавлена страна в: Максвелл.json
# Добавлена страна в: Конго.json
# Добавлена страна в: Амадей.json
# Добавлена страна в: Месси.json
# Добавлена страна в: Кашмир.json
# Добавлена страна в: Лолита.json
# Добавлена страна в: Бахати.json
# Добавлена страна в: Гастон.json
# Добавлена страна в: Мин.json
# Добавлена страна в: Грейфрайерс Бобби.json
# Добавлена страна в: Мяу.json
# Добавлена страна в: Мару.json
# Добавлена страна в: Непотопляемый Сэм.json
# Добавлена страна в: Майк.json
# Добавлена страна в: Мэй Сян.json
# Добавлена страна в: Мисс Бейкер.json
# Добавлена страна в: Му Денг.json
# Добавлена страна в: Заратустра.json
# Добавлена страна в: Олд Джок.json
# Добавлена страна в: Мисс Бизли.json
# Добавлена страна в: Гацек.json
# Добавлена страна в: Кнут.json
# Добавлена страна в: Адвайта.json
# Добавлена страна в: Бой.json
# Добавлена страна в: Крымский Том.json
# Добавлена страна в: Долли.json
# Добавлена страна в: Джуди.json
# Добавлена страна в: Оранджи.json
# Добавлена страна в: Дизель.json
# Добавлена страна в: Инджаз.json
# Добавлена страна в: Геркулес.json
# Добавлена страна в: Кокаиновый медведь.json
# Добавлена страна в: Коко.json
# Добавлена страна в: Берт.json
# Добавлена страна в: Абсент.json
# Добавлена страна в: Лил Баб.json
# Добавлена страна в: Дэш.json
# Добавлена страна в: Вилли.json
# Добавлена страна в: Мальчик.json
# Добавлена страна в: Куки.json
# Добавлена страна в: Кадо.json
# Добавлена страна в: Камиль.json
# Добавлена страна в: Отто.json
# Добавлена страна в: Блонди.json
# Добавлена страна в: Кики.json
# Добавлена страна в: Марьям.json
# Добавлена страна в: Ань-Ань.json
# Добавлена страна в: Конни Полгрейв.json
# Добавлена страна в: Милли.json
# Добавлена страна в: Амур и Тимур.json
# Добавлена страна в: Густав.json
# Добавлена страна в: Магава.json
# Добавлена страна в: Лютый.json
# Добавлена страна в: Маша.json
# Добавлена страна в: Кагуя.json
# Добавлена страна в: Алекс.json
# Добавлена страна в: Индия.json
# Добавлена страна в: Патрон.json
# Добавлена страна в: Джо Мартин.json
# Добавлена страна в: Дюймовочка.json
# Добавлена страна в: Мусташ.json
# Добавлена страна в: Муизза.json
# Добавлена страна в: Дьюи Читатель Книг.json
# Добавлена страна в: Винтер.json
# Добавлена страна в: Кабосу.json
# Добавлена страна в: Габи.json
# Добавлена страна в: Бу.json
# Добавлена страна в: Нора.json
# Добавлена страна в: Джамбо.json
# Добавлена страна в: Золушка.json
# Добавлена страна в: Мэри.json
# Добавлена страна в: Микки.json
# Добавлена страна в: Кассиус.json
# Добавлена страна в: Нола.json
# Добавлена страна в: Кейко.json
# Добавлена страна в: Кинули.json
# Добавлена страна в: Барт.json
# Добавлена страна в: Какареко.json
# Добавлена страна в: Буджан Сэнан.json
# Добавлена страна в: Пауль.json
# Добавлена страна в: Лин-Лин.json
# Добавлена страна в: Лайка.json
# Добавлена страна в: Борис.json
# Добавлена страна в: Бо Обама.json
# Добавлена страна в: Пета.json
# Добавлена страна в: Войтек.json
# Добавлена страна в: Олд Боб.json
# Добавлена страна в: Оззи.json
# Добавлена страна в: Гарриета.json

# %%
import requests

folder_path = 'famous_animals'
base_url = 'https://ru.wikipedia.org'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            if data.get('Страна', '') != "Неизвестно":
                continue

            url = data['Ссылка']
            time.sleep(1)
            response = requests.get(url, headers=headers)

            if response.status_code != 200:
                print(f"Ошибка запроса для {url}")
                continue

            soup = BeautifulSoup(response.content, 'html.parser')

            infobox = soup.find('table', {'class': 'infobox'})
            country = "Неизвестно"

            if infobox:
                rows = infobox.find_all('tr')
                for row in rows:
                    if row.th and 'страна' in row.th.text.lower():
                        country = row.td.text.strip()
                        break

            data['Страна'] = country

            with open(file_path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)

            print(f"Обновлена страна для: {data['Название']} — {country}")

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Обновлена страна для: Кузя — Россия
# Обновлена страна для: Джонатан — Остров Св. Елены
# Обновлена страна для: Железный Ковбой — Неизвестно
# Обновлена страна для: Луга — Россия
# Обновлена страна для: Абу-ль-Аббас — Неизвестно
# Обновлена страна для: Диего — Неизвестно
# Обновлена страна для: Арго — СССР
# Обновлена страна для: Большой Шлёпа — Россия
# Обновлена страна для: Мэйджор — Неизвестно
# Обновлена страна для: Пегги — Великобритания
# Обновлена страна для: Нильс Улаф — Неизвестно
# Обновлена страна для: Оскар — США
# Обновлена страна для: Анилин — СССР
# Обновлена страна для: Годзилла —
# Обновлена страна для: Дик — СССР
# Обновлена страна для: Линь Ван — Неизвестно
# Обновлена страна для: Батыр — СССР Казахстан
# Обновлена страна для: Манч — Венгрия
# Обновлена страна для: Балто — США
# Обновлена страна для: Земира — Российская империя
# Обновлена страна для: Майкл — США
# Обновлена страна для: Виннипег — Неизвестно
# Обновлена страна для: Зарафа — Неизвестно
# Обновлена страна для: Борец — Российская империя (до 1917 г.), СССР
# Обновлена страна для: Бокито — Неизвестно
# Обновлена страна для: Гли — Неизвестно
# Обновлена страна для: Барри — Италия,  Швейцария
# Обновлена страна для: Гувер — США
# Обновлена страна для: Дина — СССР
# Обновлена страна для: Барни — Неизвестно
# Обновлена страна для: Мотти — Великобритания
# Обновлена страна для: Занджир — Индия
# Обновлена страна для: Клара — Неизвестно
# Обновлена страна для: Ангалифу — Неизвестно
# Обновлена страна для: Кристал — США
# Обновлена страна для: Неджем — Древний Египет
# Обновлена страна для: Боби — Португалия
# Обновлена страна для: Максвелл — Великобритания
# Обновлена страна для: Конго — Великобритания
# Обновлена страна для: Амадей — Россия
# Обновлена страна для: Месси — Россия
# Обновлена страна для: Кашмир — Ирландия
# Обновлена страна для: Лолита — Неизвестно
# Обновлена страна для: Бахати — США
# Обновлена страна для: Гастон — Чехия
# Обновлена страна для: Мин — Исландия
# Обновлена страна для: Грейфрайерс Бобби — Шотландия
# Обновлена страна для: Мяу — США
# Обновлена страна для: Мару — Япония
# Обновлена страна для: Непотопляемый Сэм — Неизвестно
# Обновлена страна для: Майк — США
# Обновлена страна для: Мэй Сян — США
# Обновлена страна для: Мисс Бейкер — США
# Обновлена страна для: Му Денг — Таиланд
# Обновлена страна для: Заратустра — Россия
# Обновлена страна для: Олд Джок — Англия
# Обновлена страна для: Мисс Бизли — Неизвестно
# Обновлена страна для: Гацек — Польша
# Обновлена страна для: Кнут — Германия
# Обновлена страна для: Адвайта — Неизвестно
# Обновлена страна для: Бой — Неизвестно
# Обновлена страна для: Крымский Том — Неизвестно
# Обновлена страна для: Долли — Неизвестно
# Обновлена страна для: Джуди — Неизвестно
# Обновлена страна для: Оранджи — США
# Обновлена страна для: Дизель — Франция
# Обновлена страна для: Инджаз — ОАЭ
# Обновлена страна для: Геркулес — США
# Обновлена страна для: Кокаиновый медведь — США
# Обновлена страна для: Коко — Австралия
# Обновлена страна для: Берт — Австралия
# Обновлена страна для: Абсент — СССР
# Обновлена страна для: Лил Баб — США
# Обновлена страна для: Дэш — Великобритания
# Обновлена страна для: Вилли — Великобритания →  США
# Обновлена страна для: Мальчик — Россия
# Обновлена страна для: Куки — США
# Обновлена страна для: Кадо — Неизвестно
# Обновлена страна для: Камиль — Франция, Испания
# Обновлена страна для: Отто — Великобритания
# Обновлена страна для: Блонди — Нацистская Германия
# Обновлена страна для: Кики — Франция
# Обновлена страна для: Марьям — СССР
# Обновлена страна для: Ань-Ань — СССР
# Обновлена страна для: Конни Полгрейв — Неизвестно
# Обновлена страна для: Милли — США
# Обновлена страна для: Амур и Тимур — Россия
# Обновлена страна для: Густав — Бурунди
# Обновлена страна для: Магава — Неизвестно
# Обновлена страна для: Лютый — Россия
# Обновлена страна для: Маша — СССР →  Россия (город  Ярославль)
# Обновлена страна для: Кагуя — Япония
# Обновлена страна для: Алекс — Неизвестно
# Обновлена страна для: Индия — США
# Обновлена страна для: Патрон — Украина
# Обновлена страна для: Джо Мартин — Соединённые Штаты Америки
# Обновлена страна для: Дюймовочка — США
# Обновлена страна для: Мусташ — Неизвестно
# Обновлена страна для: Муизза — Неизвестно
# Обновлена страна для: Дьюи Читатель Книг — Неизвестно
# Обновлена страна для: Винтер — США
# Обновлена страна для: Кабосу — Япония
# Обновлена страна для: Габи — Израиль
# Обновлена страна для: Бу — США
# Обновлена страна для: Нора — США
# Обновлена страна для: Джамбо — Абиссиния (1860—1862)
#  Франция (1862—1865)
#  Великобритания (1865—1882)
#  США (1882—1885)
# Обновлена страна для: Золушка — Россия
# Обновлена страна для: Мэри — США
# Обновлена страна для: Микки — Россия
# Обновлена страна для: Кассиус — Австралия
# Обновлена страна для: Нола — США
# Обновлена страна для: Кейко — Неизвестно
# Обновлена страна для: Кинули — СССР
# Обновлена страна для: Барт — США
# Обновлена страна для: Какареко — Бразилия
# Обновлена страна для: Буджан Сэнан —
# Обновлена страна для: Пауль — Неизвестно
# Обновлена страна для: Лин-Лин — Китай  Япония
# Обновлена страна для: Лайка — СССР
# Обновлена страна для: Борис — Бельгия
# Обновлена страна для: Бо Обама — Неизвестно
# Обновлена страна для: Пета — Великобритания
# Обновлена страна для: Войтек — Неизвестно
# Обновлена страна для: Олд Боб — США
# Обновлена страна для: Оззи — Неизвестно
# Обновлена страна для: Гарриета — Австралия

# %%
country_mapping = {
    'СССР': 'Россия',
    'Российская империя': 'Россия',
    'Англия': 'Великобритания',
    'Шотландия': 'Великобритания',
    'Уэльс': 'Великобритания',
    'Северная Ирландия': 'Великобритания',
    'Ирландия': 'Великобритания',
    'Остров Св. Елены': 'Великобритания',
    'Нацистская Германия': 'Германия',
    'Великобритания →  США': 'Великобритания',
    'Древний Египет': 'Египет',
    'Италия,  Швейцария': 'Швейцария',
    'Китай  Япония': 'Китай',
    'Соединённые Штаты Америки': 'США',
}

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            country = data.get('Страна', '').strip()

            for old, new in country_mapping.items():
                if old.lower() in country.lower():
                    print(f"Изменяем для {data['Название']}: {country} ➔ {new}")
                    data['Страна'] = new
                    break

            with open(file_path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Изменяем для Джонатан: Остров Св. Елены ➔ Великобритания
# Изменяем для Арго: СССР ➔ Россия
# Изменяем для Анилин: СССР ➔ Россия
# Изменяем для Дик: СССР ➔ Россия
# Изменяем для Батыр: СССР Казахстан ➔ Россия
# Изменяем для Земира: Российская империя ➔ Россия
# Изменяем для Борец: Российская империя (до 1917 г.), СССР ➔ Россия
# Изменяем для Дина: СССР ➔ Россия
# Изменяем для Неджем: Древний Египет ➔ Египет
# Изменяем для Кашмир: Ирландия ➔ Великобритания
# Изменяем для Грейфрайерс Бобби: Шотландия ➔ Великобритания
# Изменяем для Олд Джок: Англия ➔ Великобритания
# Изменяем для Абсент: СССР ➔ Россия
# Изменяем для Блонди: Нацистская Германия ➔ Германия
# Изменяем для Марьям: СССР ➔ Россия
# Изменяем для Ань-Ань: СССР ➔ Россия
# Изменяем для Маша: СССР →  Россия (город  Ярославль) ➔ Россия
# Изменяем для Джо Мартин: Соединённые Штаты Америки ➔ США
# Изменяем для Кинули: СССР ➔ Россия
# Изменяем для Лайка: СССР ➔ Россия

# %%
corrections = {
    "Нильс Улаф": "Норвегия",
    "Линь Ван": "Тайвань",
    "Виннипег": "Канада",
    "Зарафа": "Франция",
    "Бокито": "Нидерланды",
    "Гли": "Турция",
    "Барни": "США",
    "Клара": "Германия",
    "Ангалифу": "ЮАР",
    "Лолита": "США",
    "Непотопляемый Сэм": "Германия",
    "Мисс Бизли": "США",
    "Адвайта": "Индия",
    "Бой": "Великобритания",
    "Крымский Том": "Россия",
    "Долли": "Великобритания",
    "Джуди": "Великобритания",
    "Кадо": "США",
    "Камиль": "Франция",
    "Конни Полгрейв": "Россия",
    "Магава": "Камбоджа",
    "Алекс": "США",
    "Мусташ": "Франция",
    "Муизза": "Египет",
    "Дьюи Читатель Книг": "США",
    "Джамбо": "Великобритания",
    "Кейко": "Исландия",
    "Буджан Сэнан": "Турция",
    "Пауль": "Германия",
    "Бо Обама": "США",
    "Войтек": "Польша",
    "Оззи": "США",
    "Железный Ковбой": "Россия",
    "Абу-ль-Аббас": "Иран",
    "Диего": "Эквадор",
    "Мэйджор": "США",
    "Годзилла": "Украина"
}

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            name = data.get('Название', '')

            if name in corrections:
                old_country = data.get('Страна', '')
                new_country = corrections[name]

                # Обновляем страну
                data['Страна'] = new_country

                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=4)

                print(f"Обновлено для {name}: {old_country} ➔ {new_country}")

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")
# Out:
# Обновлено для Железный Ковбой: Неизвестно ➔ Россия
# Обновлено для Абу-ль-Аббас: Неизвестно ➔ Иран
# Обновлено для Диего: Неизвестно ➔ Эквадор
# Обновлено для Мэйджор: Неизвестно ➔ США
# Обновлено для Нильс Улаф: Неизвестно ➔ Норвегия
# Обновлено для Годзилла:  ➔ Украина
# Обновлено для Линь Ван: Неизвестно ➔ Тайвань
# Обновлено для Виннипег: Неизвестно ➔ Канада
# Обновлено для Зарафа: Неизвестно ➔ Франция
# Обновлено для Бокито: Неизвестно ➔ Нидерланды
# Обновлено для Гли: Неизвестно ➔ Турция
# Обновлено для Барни: Неизвестно ➔ США
# Обновлено для Клара: Неизвестно ➔ Германия
# Обновлено для Ангалифу: Неизвестно ➔ ЮАР
# Обновлено для Лолита: Неизвестно ➔ США
# Обновлено для Непотопляемый Сэм: Неизвестно ➔ Германия
# Обновлено для Мисс Бизли: Неизвестно ➔ США
# Обновлено для Адвайта: Неизвестно ➔ Индия
# Обновлено для Бой: Неизвестно ➔ Великобритания
# Обновлено для Крымский Том: Неизвестно ➔ Россия
# Обновлено для Долли: Неизвестно ➔ Великобритания
# Обновлено для Джуди: Неизвестно ➔ Великобритания
# Обновлено для Кадо: Неизвестно ➔ США
# Обновлено для Камиль: Франция, Испания ➔ Франция
# Обновлено для Конни Полгрейв: Неизвестно ➔ Россия
# Обновлено для Магава: Неизвестно ➔ Камбоджа
# Обновлено для Алекс: Неизвестно ➔ США
# Обновлено для Мусташ: Неизвестно ➔ Франция
# Обновлено для Муизза: Неизвестно ➔ Египет
# Обновлено для Дьюи Читатель Книг: Неизвестно ➔ США
# Обновлено для Джамбо: Абиссиния (1860—1862)
#  Франция (1862—1865)
#  Великобритания (1865—1882)
#  США (1882—1885) ➔ Великобритания
# Обновлено для Кейко: Неизвестно ➔ Исландия
# Обновлено для Буджан Сэнан:  ➔ Турция
# Обновлено для Пауль: Неизвестно ➔ Германия
# Обновлено для Бо Обама: Неизвестно ➔ США
# Обновлено для Войтек: Неизвестно ➔ Польша
# Обновлено для Оззи: Неизвестно ➔ США

# %%
bad_countries = ['Великобритания → США', 'Италия', 'Швейцария']

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            country = data.get('Страна', '').strip()

            if country in bad_countries:
                print(f"Удаляю файл {filename} (страна: {country})")
                os.remove(file_path)

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

# %%
countries = set()

missing_description = []
missing_type = []
missing_birth = []
missing_country = []

total_files = 0

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            total_files += 1

            country = data.get('Страна', '').strip()
            if country:
                countries.add(country)
            if country.lower() == 'неизвестно' or not country:
                missing_country.append(filename)

            # Проверка на пропуски
            if data.get('Описание', '').strip() == "Описание недоступно." or not data.get('Описание', '').strip():
                missing_description.append(filename)

            if data.get('Вид животного', '').strip().lower() == 'неизвестно' or not data.get('Вид животного', '').strip():
                missing_type.append(filename)

            if data.get('Дата рождения', '').strip().lower() == 'неизвестно' or not data.get('Дата рождения', '').strip():
                missing_birth.append(filename)

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

print(f"Всего файлов: {total_files}\n")

print("Уникальные страны:")
for c in sorted(countries):
    print("-", c)

print("\nФайлы с пропущенным описанием:", len(missing_description))

print("Файлы с пропущенным видом животного:", len(missing_type))

print("Файлы с пропущенной датой рождения:", len(missing_birth))

print("Файлы с пропущенной страной:", len(missing_country))
# Out:
# Всего файлов: 126
#
# Уникальные страны:
# - Австралия
# - Бельгия
# - Бразилия
# - Бурунди
# - Великобритания
# - Великобритания →  США
# - Венгрия
# - Германия
# - Египет
# - Израиль
# - Индия
# - Иран
# - Исландия
# - Италия,  Швейцария
# - Камбоджа
# - Канада
# - Китай  Япония
# - Нидерланды
# - Норвегия
# - ОАЭ
# - Польша
# - Португалия
# - Россия
# - США
# - Таиланд
# - Тайвань
# - Турция
# - Украина
# - Франция
# - Чехия
# - Эквадор
# - ЮАР
# - Япония
#
# Файлы с пропущенным описанием: 0
# Файлы с пропущенным видом животного: 0
# Файлы с пропущенной датой рождения: 0
# Файлы с пропущенной страной: 0

# %%
import re
import os
import json

def extract_year(text):
    """
    Извлекает первый нормальный год (4 цифры) из текста с учетом различных вариантов форматов дат.
    Если года нет, возвращает None.
    """
    text = re.sub(r'\(.*?\)', '', text)
    text = re.sub(r'[^0-9а-яА-ЯёЁ\s]', '', text)

    # Регулярное выражение для нахождения года
    years = re.findall(r'\b\d{4}\b', text)

    if years:
        return years[0]

    if 'по' in text:
        range_years = re.findall(r'\b\d{4}\b', text)
        if range_years:
            return range_years[0]

    if 'примерно' in text or '?' in text:
        possible_years = re.findall(r'\b\d{4}\b', text)
        if possible_years:
            return possible_years[0]

    if 'не позднее' in text:
        possible_years = re.findall(r'\b\d{4}\b', text)
        if possible_years:
            return possible_years[0]

    return None

folder_path = 'famous_animals'

unique_years = set()

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        path = os.path.join(folder_path, filename)

        with open(path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        birth_date = data.get('Дата рождения', '').strip()

        year = extract_year(birth_date)

        if year:
            unique_years.add(year)

unique_years = sorted(unique_years)
print(f"Найдено уникальных годов: {len(unique_years)}")
for year in unique_years:
    print("-", year)
# Out:
# Найдено уникальных годов: 77
# - 1479
# - 1499
# - 1638
# - 1738
# - 1750
# - 1778
# - 1799
# - 1800
# - 1830
# - 1832
# - 1847
# - 1849
# - 1855
# - 1859
# - 1860
# - 1863
# - 1868
# - 1886
# - 1914
# - 1915
# - 1917
# - 1919
# - 1924
# - 1933
# - 1935
# - 1936
# - 1939
# - 1941
# - 1942
# - 1944
# - 1945
# - 1951
# - 1952
# - 1954
# - 1955
# - 1957
# - 1961
# - 1963
# - 1970
# - 1971
# - 1972
# - 1973
# - 1974
# - 1976
# - 1977
# - 1978
# - 1981
# - 1983
# - 1985
# - 1987
# - 1988
# - 1989
# - 1990
# - 1991
# - 1992
# - 1994
# - 1996
# - 1998
# - 1999
# - 2000
# - 2001
# - 2002
# - 2004
# - 2005
# - 2006
# - 2007
# - 2008
# - 2009
# - 2010
# - 2011
# - 2012
# - 2013
# - 2015
# - 2017
# - 2018
# - 2019
# - 2024

# %%
import os
import json

folder_path = 'famous_animals'

years = set()

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        year = data.get('Дата рождения', '').strip()

        if year and year != "Неизвестно":
            years.add(year)

years = sorted(years)
print(f"Найдено уникальных годов: {len(years)}")
for year in years:
    print("-", year)
# Out:
# Найдено уникальных годов: 123
# - 1 мая 2001(2001-05-01)
# - 1 октября 2009(2009-10-01) (15 лет)
# - 10 декабря 2005
# - 10 июля 2024 (5 месяцев)
# - 10 октября 2005(2005-10-10)
# - 10 сентября 2004(2004-09-10)
# - 10 февраля 1919(1919-02-10)
# - 11 июля 1978(1978-07-11)
# - 11 мая 1992(1992-05-11)
# - 12 января 1985(1985-01-12)
# - 13 июля 1990(1990-07-13)
# - 14 марта 1996(1996-03-14)
# - 14 февраля 1954(1954-02-14)
# - 14 февраля 1989(1989-02-14)
# - 15 июня 1868(1868-06-15)
# - 16 марта 2006(2006-03-16)
# - 17 марта 1973(1973-03-17)
# - 17 марта 2017 г.
# - 17 января 2018(2018-01-17) (7 лет)
# - 1738
# - 1778(1778)
# - 18 ноября 1987(1987-11-18)
# - 1800(1800)
# - 1825[1]
# - 1830(1830)
# - 1855(1855)
# - 1859(1859)
# - 19 января 1977(1977-01-19)
# - 1911-1913
# - 1914
# - 1917 (примерно)
# - 1930-е
# - 1936 год
# - 1941(1941)
# - 1942 или 1941
# - 1952(1952)
# - 1954(1954)
# - 1955(1955)
# - 1957(1957)
# - 1961
# - 1963(1963)
# - 1964–1967[1]
# - 1970(1970)
# - 1971 (?)
# - 1972
# - 1976[1]
# - 1983 или 1984
# - 1988(1988)
# - 1991 (?)
# - 1994(1994)
# - 1996
# - 2 ноября 2005(2005-11-02)
# - 20 апреля 1935(1935-04-20)
# - 20 апреля 1945(1945-04-20)
# - 20 июля 2019(2019-07-20) (5 лет)
# - 2002
# - 2005(2005)
# - 2006[1]
# - 2011 год
# - 2011 или 2012 год
# - 2011(2011)
# - 2018 (7 лет)
# - 21 декабря 2017(2017-12-21) (7 лет)
# - 21 июня 2011(2011-06-21)
# - 22 июля 1998(1998-07-22) (26 лет)
# - 24 мая 1970(1970-05-24)
# - 24 мая 2007(2007-05-24) (17 лет)
# - 26 января 2008(2008-01-26)
# - 28 октября 2004(2004-10-28)
# - 29 декабря 1983(1983-12-29)
# - 3 января 1999(1999-01-03)
# - 30 июня 1933(1933-06-30)
# - 30 октября 2015(2015-10-30) (9 лет)
# - 30 сентября 2000(2000-09-30)
# - 31 октября 1981(1981-10-31)
# - 31 января 1961 года
# - 4 мая 2010(2010-05-04)
# - 5 декабря 2006(2006-12-05)
# - 5 июля 1996(1996-07-05)[1]
# - 5 сентября 1985
# - 6 мая 1994(1994-05-06) (30 лет)
# - 7 января 1992(1992-01-07)
# - 8 апреля 2009(2009-04-08) (16 лет)
# - 8 июля 1939(1939-07-08)
# - 9 апреля 2005(2005-04-09)
# - 9 октября 2008(2008-10-09)
# - VI век
# - XX век
# - Амур — 2 апреля 2012 (13 лет)Тимур — 9 июля 2014
# - Не позднее 1991 года
# - Ноябрь 2013
# - апрель 2004
# - декабрь 1942
# - до 1941
# - конец 1900-х – начало 1910-х гг.
# - май 1924 г.
# - март 1944
# - не ранее 1479 г. до н.э.
# - не позднее 1951
# - не ранее 1750 и не позднее 1856
# - неизвестна
# - ок. 1499
# - ок. 1638 года
# - ок. 1863
# - ок. 1976 года
# - ок. 2005
# - ок. 2008
# - ок. 2010
# - ок. 1849
# - ок. 25 декабря 1860
# - около 1830
# - около 1832 года
# - около 1847
# - около 1914
# - около 1915
# - около 1920/1930 годов
# - около 1974
# - около 2004[1][2]
# - около 2013
# - около 770
# - октябрь 1963
# - прим. 1886
# - сентябрь 1799

# %%
import shutil
shutil.make_archive('архив', 'zip', 'famous_animals')
# Out:
# '/content/архив.zip'

# %% [markdown]
# ### 1. Построить базу знаний в любой предметной области, сформировав массив документов (например, публикаций или файлов на каком-либо портале или набор файлов на компьютере или сервере и т.п.) и построить граф знаний об этих документах

# %%
# !pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.11/dist-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis) (4.0.5)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)

# %%
import os
import json
import networkx as nx
from pyvis.network import Network

# %%
folder_path = 'famous_animals'

# %%
G = nx.Graph()

# %%
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            animal = data.get('Название', 'Без имени')
            animal_type = data.get('Вид животного', 'Неизвестно')
            birth_date = data.get('Дата рождения', 'Неизвестно')
            country = data.get('Страна', 'Неизвестно')

            # Узел животного
            G.add_node(animal, label=animal, title=f"Животное: {animal}\nВид: {animal_type}\nДата рождения: {birth_date}\nСтрана: {country}")

            # Узел страны
            if not G.has_node(country):
                G.add_node(country, label=country, title=f"Страна: {country}")

            G.add_edge(animal, country, relation='родом из')

            # Узел вида животного
            if not G.has_node(animal_type):
                G.add_node(animal_type, label=animal_type, title=f"Вид животного: {animal_type}")

            G.add_edge(animal, animal_type, relation='является')

        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

# %%
net = Network(height="750px", width="100%", bgcolor="#ffffff", font_color="black", notebook=True)

net.from_nx(G)

# Включить физику для удобства перемещения
net.toggle_physics(True)

net.save_graph("famous_animals_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %% [markdown]
# ### 2. Реализовать сервис краткого описания каждого документа в базе знаний (абстракт, автореферат - summary)

# %%
def get_summary(animal_name, folder_path='famous_animals'):
    """
    Получает краткое описание животного по его имени файла.
    """
    filename = f"{animal_name}.json"
    path = os.path.join(folder_path, filename)

    if not os.path.exists(path):
        return "Файл не найден."

    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    name = data.get('Название', 'Неизвестно')
    animal_type = data.get('Вид животного', 'Неизвестно')
    country = data.get('Страна', 'Неизвестно')
    birth_date = data.get('Дата рождения', 'Неизвестно')
    description = data.get('Описание', 'Описание недоступно.')

    summary = (f"{name} — это {animal_type}, родом из {country}. "
               f"Родился в {birth_date}. Краткое описание: {description}")

    return summary

# %%
print(get_summary("Пета"))
# Out:
# Пета — это Домашняя кошка, родом из Великобритания. Родился в октябрь 1963. Краткое описание: Пета (англ. Peta) — кошка, служившая главным мышеловом в кабинете правительства Соединенного Королевства в период с 1964 года и между 1969 и 1976 годами и была первой кошкой-самкой в этой роли. Она стала заменой Питеру III, который умер в возрасте 16 лет в 1964 году[1]. После его смерти, лейтенант-губернатор острова Мэн, сэр Рональд Гарви, предложил, чтобы Питера III заменила мэнская кошка и отправил Пету в кабинет. Она была ленивой и шумной, и к 1969 году некоторые государственные служащие пытались убрать её из кабинета министров, но этого не произошло из-за риска ухудшения репутации. Больше о ней не слышали, пока ответ представителю общественности в 1976 не показал, что её перевели в дом государственного служащего. Её преемником был Уилберфорс, который стал следующим Главным мышеловом в 1970-х годах[2].

# %% [markdown]
# ### 3. Реализовать сервис поиска по запросу внутри базы знаний (вопрос-ответный модуль)

# %%
def search_animals(query: str, folder_path='famous_animals'):
    """
    Ищет животных по запросу внутри базы знаний.
    Запрос ищет по названию, виду, стране и описанию.
    """
    results = []

    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            path = os.path.join(folder_path, filename)

            with open(path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            name = data.get('Название', '').lower()
            animal_type = data.get('Вид животного', '').lower()
            country = data.get('Страна', '').lower()
            birth_date = data.get('Дата рождения', '').lower()
            description = data.get('Описание', '').lower()

            # если запрос содержится в любом из полей
            if (query.lower() in name or
                query.lower() in animal_type or
                query.lower() in country or
                query.lower() in birth_date or
                query.lower() in description):
                results.append(data)

    return results

# %%
query = "Россия"
found = search_animals(query)

print(f"Найдено животных: {len(found)}")
for animal in found:
    print(f"- {animal['Название']} ({animal['Вид животного']}, {animal['Страна']})")
# Out:
# Найдено животных: 27
# - Кузя (Тигр, подвид Уссурийский (амурский) тигр, Россия)
# - Железный Ковбой (лошадь, Россия)
# - Луга (Жираф, Россия)
# - Арго (Волк, Россия)
# - Большой Шлёпа (каракал, Россия)
# - Анилин (Домашняя лошадь, Россия)
# - Дик (Собака, Россия)
# - Батыр (индийский слон, Россия)
# - Земира (собака, Россия)
# - Борец (Бурый медведь, Россия)
# - Дина (Собака, Россия)
# - Амадей (Тигр, Россия)
# - Месси (Пума, Россия)
# - Заратустра (Домашняя кошка, Россия)
# - Крымский Том (Кошка, Россия)
# - Абсент (дикая лошадь (подвид домашняя лошадь), Россия)
# - Мальчик (собака, Россия)
# - Марьям (Бурый медведь, Россия)
# - Ань-Ань (Большая панда, Россия)
# - Конни Полгрейв (Собака (Canis familiaris), Россия)
# - Амур и Тимур (амурский тигр и козёл домашний, Россия)
# - Лютый (Panthera tigris altaica, Россия)
# - Маша (бурый медведь (европейский подвид), Россия)
# - Золушка (Тигр, подвид Уссурийский (амурский) тигр, Россия)
# - Микки (обыкновенный шимпанзе, Россия)
# - Кинули (Лев, Россия)
# - Лайка (Собака (Canis familiaris), Россия)
